# %%
import matplotlib.pyplot as plt

# Erste Datenreihe
x = [4, 10, 15, 17, 18, 19, 20, 30, 50, 80, 100, 200, 365]
y1 = [578826.909, 485208.397, 482245.463,  264786.783, 250696.926, 239341.790, 239675.119, 253060.948, 221913.563, 251438.635, 243291.741, 209572.696, 207126.715]
y2 = [1116163.19, 1019437.9188, 1022610.8227, 795774.29760, 774193.90479, 739924.20392 , 738268.63786, 750933.27889, 736193.37126, 768519.41004, 718101.764, 619153.25004, 656253.81555 ]

plt.figure()
plt.plot(x, y1, marker='o')
plt.xlabel('number of typical days in time aggregation')
plt.ylabel('Best Bound')
plt.grid(True)
plt.show()



plt.figure()
plt.plot(x, y1, marker='o', label='Best Bound')
plt.plot(x, y2, marker='x', label='Upper Bound (Incumbent)', color='red')  # Zweite Datenreihe in anderer Farbe und mit anderem Marker

plt.xlabel('Number of typical days in time aggregation')
plt.ylabel('Bounds')
plt.grid(True)
plt.legend()
plt.show()
